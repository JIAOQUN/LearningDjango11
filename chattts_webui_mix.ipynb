# %% [markdown]
# <a href="https://colab.research.google.com/github/JIAOQUN/LearningDjango11/blob/master/chattts_webui_mix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Markdown

message = """
### 🌟 如果你觉得 ChatTTS 和 ChatTTS_colab 项目对你有帮助，请访问以下链接给它们点个星星吧！🌟

- [ChatTTS 项目](https://github.com/2noise/ChatTTS)

- [ChatTTS_colab 项目](https://github.com/6drf21e/ChatTTS_colab)

感谢你的支持！

### 运行方法 ###

- 点击菜单栏的--代码执行程序--全部运行即可
- 执行后在下方的日志中找到类似

  Running on public URL: https://**************.gradio.live  <-这个就是可以访问的公网地址

安装包的时候提示要重启 请点**"否"**


"""
display(Markdown(message))
# Out:
# ### 🌟 如果你觉得 ChatTTS 和 ChatTTS_colab 项目对你有帮助，请访问以下链接给它们点个星星吧！🌟
#
# - [ChatTTS 项目](https://github.com/2noise/ChatTTS)
#
# - [ChatTTS_colab 项目](https://github.com/6drf21e/ChatTTS_colab)
#
# 感谢你的支持！
#
# ### 运行方法 ###
#
# - 点击菜单栏的--代码执行程序--全部运行即可
# - 执行后在下方的日志中找到类似
#
#   Running on public URL: https://**************.gradio.live  <-这个就是可以访问的公网地址
#
# 安装包的时候提示要重启 请点**"否"**

# %%
# !git clone -q https://github.com/6drf21e/ChatTTS_colab
# %cd ChatTTS_colab
# !git clone -q https://github.com/2noise/ChatTTS
# %cd ChatTTS
# !git checkout -q f4c8329
# %cd ..
# !mv ChatTTS abc
# !mv abc/ChatTTS ./ChatTTS
# !pip install -q omegaconf vocos vector_quantize_pytorch gradio cn2an pypinyin openai jieba WeTextProcessing
# 启动 Gradio 有公网地址
# !python webui_mix.py --share
# Out:
# /content/ChatTTS_colab
# /content/ChatTTS_colab/ChatTTS
# /content/ChatTTS_colab
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 30.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 53.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 62.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 12.6 MB/s eta 0:00:00
# ...
